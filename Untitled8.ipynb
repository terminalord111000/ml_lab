# %% [markdown]
# <a href="https://colab.research.google.com/github/terminalord111000/ml_lab/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - import request and bs4
# - request site and get response
# -
