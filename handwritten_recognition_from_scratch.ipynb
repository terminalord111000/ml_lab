# %% [markdown]
# <a href="https://colab.research.google.com/github/terminalord111000/ml_lab/blob/main/handwritten_recognition_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - load data
# - normalize
# - one_hot encoding
# - train_ test split
# - mlp design

# %%
from sklearn.datasets import load_digits
import numpy as np

# %%
digits = load_digits()
x = digits.data.astype(np.float64)
y = digits.target

# %%
X/=16.0

# %%
def one_hot(y, num_classes=10):
  return np.eye(num_classes)[y]

y = one_hot(y)
