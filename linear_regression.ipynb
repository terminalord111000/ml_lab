# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([1,2,3,4,5], dtype=float)
Y = 2*X

# %%
learning_rate = 0.01
m = 0.0
b = 0.0
epochs = 100
n = len(X)
plt.ion()

# %%
for epoch in range(epochs):

  plt.clf()

  Y_pred = m*X+b

  dm = (2/n)*sum(X*(Y_pred - Y))
  db = (2/n)*sum((Y_pred - Y))

  m = m-learning_rate*dm
  b= b-learning_rate*db

  if epoch%50 == 0:
    plt.scatter(X,Y, color="blue")
    plt.plot(X,Y_pred,label=f'y={m:.2f}x + {b:.2f}')
    plt.title(f"Epoch {epoch}")
    plt.legend()
    plt.pause(0.5)

plt.ioff()  # turn off interactive mode
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1882524697.py in <cell line: 0>()
#      15   plt.title(f"Epoch {epoch}")
#      16   plt.legend()
# ---> 17   plt.pause(0.5)
#      18
#      19 plt.ioff()  # turn off interactive mode
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in pause(interval)
#     756             canvas.draw_idle()
#     757         show(block=False)
# --> 758         canvas.start_event_loop(interval)
#     759     else:
#     760         time.sleep(interval)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in start_event_loop(self, timeout)
#    2363         while self._looping and counter * timestep < timeout:
#    2364             self.flush_events()
# -> 2365             time.sleep(timestep)
#    2366             counter += 1
#    2367
#
# KeyboardInterrupt:
